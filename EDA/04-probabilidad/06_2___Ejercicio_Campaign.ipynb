# %% [markdown]
# <a href="https://colab.research.google.com/github/JotaBlanco/TheValley/blob/main/EDA/04-probabilidad/06_2___Ejercicio_Campaign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_url = "https://raw.githubusercontent.com/JotaBlanco/TheValley/refs/heads/main/Data/marketing_AB.csv"
df = pd.read_csv(df_url).drop(columns=["Unnamed: 0"])
df.columns = ['user_id', 'test_group', 'converted', 'total_ads', 'most_ads_day', 'most_ads_hour']
df["converted"] = df["converted"].astype(int)
df
# Out:
#         user_id test_group  converted  total_ads most_ads_day  most_ads_hour
# 0       1069124         ad          0        130       Monday             20
# 1       1119715         ad          0         93      Tuesday             22
# 2       1144181         ad          0         21      Tuesday             18
# 3       1435133         ad          0        355      Tuesday             10
# 4       1015700         ad          0        276       Friday             14
# ...         ...        ...        ...        ...          ...            ...
# 588096  1278437         ad          0          1      Tuesday             23
# 588097  1327975         ad          0          1      Tuesday             23
# 588098  1038442         ad          0          3      Tuesday             23
# 588099  1496395         ad          0          1      Tuesday             23
# 588100  1237779         ad          0          1      Tuesday             23
#
# [588101 rows x 6 columns]

# %% [markdown]
# ## Ejercicio 1:
# Calcula las probabilidades de:
# - Conversión
# - De estar en el grupo con anuncios o de control
# - De cada día de la semana de ser el que más anuncios tuvo
# - De cada hora del día

# %% [markdown]
# # Ejercicio 2:
# Calcula las probabilidades condicionadas de:
# - Conversión según el grupo (anuncios o control)
# - De conversión según el día de la semana en que más anuncios se mostraron
# - Probabiliad de conversión para los que han tenido más de 200 anuncios mostrados
# - Probabilidad de conversión para los que han tenido menos de 5 anuncios mostrados
